# %% [markdown]
# ## Data Analyse

# %%
import pandas as pd

# %%
df = pd.read_csv('new_data.csv')
df
# Out:
#      Unnamed: 0                                                url  \
# 0             0  https://www.goodreads.com/book/show/2767052-th...
# 1             1  https://www.goodreads.com/book/show/2.Harry_Po...
# 2             2  https://www.goodreads.com/book/show/2657.To_Ki...
# 3             3  https://www.goodreads.com/book/show/1885.Pride...
# 4             4  https://www.goodreads.com/book/show/19063.The_...
# ..          ...                                                ...
# 995         995  https://www.goodreads.com/book/show/8685612-th...
# 996         996  https://www.goodreads.com/book/show/7402393-ni...
# 997         997  https://www.goodreads.com/book/show/17343.Till...
# 998         998  https://www.goodreads.com/book/show/32829.Jour...
# 999         999  https://www.goodreads.com/book/show/249.Tropic...
#
#                                                  title           author  \
# 0              The Hunger Games (The Hunger Games, #1)  Suzanne Collins
# 1    Harry Potter and the Order of the Phoenix (Har...     J.K. Rowling
# 2                                To Kill a Mockingbird       Harper Lee
# 3                                  Pride and Prejudice      Jane Austen
# 4                                       The Book Thief     Markus Zusak
# ..                                                 ...              ...
# 995                  The Iron Queen (The Iron Fey, #3)     Julie Kagawa
# 996  Nightshade (Nightshade, #1; Nightshade World, #4)    Andrea Cremer
# 997                                 Till We Have Faces       C.S. Lewis
# 998                 Journey to the Center of the Earth      Jules Verne
# 999                      Tropic of Cancer (Tropic, #1)     Henry Miller
#
#      num_rating  avg_rating  minmax_norm_ratings  mean_norm_ratings
# 0       7251682        4.32             6.225806           2.399761
# 1       2881319        4.50             7.270968           3.444923
# 2       5174551        4.27             5.935484           2.109439
# 3       3523201        4.28             5.993548           2.167503
# 4       2130791        4.38             6.574194           2.748148
# ..          ...         ...                  ...                ...
# 995      103998        4.19             5.470968           1.644923
# 996       84096        4.00             4.367742           0.541697
# 997       61709        4.15             5.238710           1.412665
# 998      171939        3.86             3.554839          -0.271206
# 999       67132        3.68             2.509677          -1.316368
#
# [1000 rows x 8 columns]

# %%
def author_best_book(author, df):
    return df[df['author']==author].sort_values('minmax_norm_ratings', ascending=False)['title'].head(1).item(), df[df['author']==author].sort_values('minmax_norm_ratings', ascending=False)['minmax_norm_ratings'].head(1).item() 
ans = author_best_book(author='Jules Verne', df=df)
print("Author's best book is:", ans[0] ,"  The Rating of the book is:", ans[1])
# Out:
# Author's best book is: Around the World in Eighty Days   The Rating of the book is: 4.019354838709678
