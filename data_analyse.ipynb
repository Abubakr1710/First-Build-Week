# %% [markdown]
# ## Data Analyse

# %%
import pandas as pd

# %%
df = pd.read_csv('buildData.csv')
df
# Out:
#      Unnamed: 0                                              TITLE  \
# 0             1            The Hunger Games (The Hunger Games, #1)
# 1             2  Harry Potter and the Order of the Phoenix (Har...
# 2             3                              To Kill a Mockingbird
# 3             4                                Pride and Prejudice
# 4             5                                     The Book Thief
# ..          ...                                                ...
# 995         996                  The Iron Queen (The Iron Fey, #3)
# 996         997  Nightshade (Nightshade, #1; Nightshade World, #4)
# 997         998                                 Till We Have Faces
# 998         999                 Journey to the Center of the Earth
# 999        1000                      Tropic of Cancer (Tropic, #1)
#
#               AUTHOR  PAGES  RATING  REVIEWERS PLACE (COUNTRY) ORIGINAL YEAR  \
# 0    Suzanne Collins    374    4.32    7251682  United Kingdom          2003
# 1       J.K. Rowling    870    4.50    2881319   United States          1960
# 2         Harper Lee    336    4.27    5174551  United Kingdom          1813
# 3        Jane Austen    279    4.28    3523201            None          2005
# 4       Markus Zusak    552    4.38    2130791   United States          2005
# ..               ...    ...     ...        ...             ...           ...
# 995     Julie Kagawa    384    4.19     103998   United States          None
# 996    Andrea Cremer    452    4.00      84096          Greece          None
# 997       C.S. Lewis    313    4.15      61709         Germany          1956
# 998      Jules Verne    240    3.86     171939          France          1864
# 999     Henry Miller    318    3.68      67132            NONE          1934
#
#                                              URL LINKS
# 0    https://www.goodreads.com/book/show/2767052-th...
# 1    https://www.goodreads.com/book/show/2.Harry_Po...
# 2    https://www.goodreads.com/book/show/2657.To_Ki...
# 3    https://www.goodreads.com/book/show/1885.Pride...
# 4    https://www.goodreads.com/book/show/19063.The_...
# ..                                                 ...
# 995  https://www.goodreads.com/book/show/8685612-th...
# 996  https://www.goodreads.com/book/show/7402393-ni...
# 997  https://www.goodreads.com/book/show/17343.Till...
# 998  https://www.goodreads.com/book/show/32829.Jour...
# 999  https://www.goodreads.com/book/show/249.Tropic...
#
# [1000 rows x 9 columns]

# %%
ndata = df.mask(df.eq('NONE')).dropna()
nedata = ndata.mask(df.eq('None')).dropna()
nedata
# Out:
#      Unnamed: 0                                              TITLE  \
# 0             1            The Hunger Games (The Hunger Games, #1)
# 1             2  Harry Potter and the Order of the Phoenix (Har...
# 2             3                              To Kill a Mockingbird
# 4             5                                     The Book Thief
# 14           15                         The Picture of Dorian Gray
# ..          ...                                                ...
# 984         985                                           Timeline
# 989         990                  Magician (The Riftwar Saga, #1-2)
# 992         993       Gödel, Escher, Bach: An Eternal Golden Braid
# 997         998                                 Till We Have Faces
# 998         999                 Journey to the Center of the Earth
#
#                     AUTHOR  PAGES  RATING  REVIEWERS PLACE (COUNTRY)  \
# 0          Suzanne Collins    374    4.32    7251682  United Kingdom
# 1             J.K. Rowling    870    4.50    2881319   United States
# 2               Harper Lee    336    4.27    5174551  United Kingdom
# 4             Markus Zusak    552    4.38    2130791   United States
# 14             Oscar Wilde    272    4.10    1167622          France
# ..                     ...    ...     ...        ...             ...
# 984       Michael Crichton    489    3.86     197521   United States
# 989       Raymond E. Feist    681    4.30      63929   United States
# 992  Douglas R. Hofstadter    777    4.28      46312   United States
# 997             C.S. Lewis    313    4.15      61709         Germany
# 998            Jules Verne    240    3.86     171939          France
#
#     ORIGINAL YEAR                                          URL LINKS
# 0            2003  https://www.goodreads.com/book/show/2767052-th...
# 1            1960  https://www.goodreads.com/book/show/2.Harry_Po...
# 2            1813  https://www.goodreads.com/book/show/2657.To_Ki...
# 4            2005  https://www.goodreads.com/book/show/19063.The_...
# 14           2003  https://www.goodreads.com/book/show/5297.The_P...
# ..            ...                                                ...
# 984          1999  https://www.goodreads.com/book/show/7669.Timeline
# 989          1982  https://www.goodreads.com/book/show/43916.Magi...
# 992          1979  https://www.goodreads.com/book/show/24113.G_de...
# 997          1956  https://www.goodreads.com/book/show/17343.Till...
# 998          1864  https://www.goodreads.com/book/show/32829.Jour...
#
# [334 rows x 9 columns]

# %%
def author_best_book(author, df):
    return df[df['author']==author].sort_values('minmax_norm_ratings', ascending=False)['title'].head(1).item(), df[df['author']==author].sort_values('minmax_norm_ratings', ascending=False)['minmax_norm_ratings'].head(1).item() 
ans = author_best_book(author='Harper Lee', df=df)
print("Author's best book is:", ans[0] ,"  The Rating of the book is:", ans[1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\envs\ai\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///~/Anaconda3/envs/ai/lib/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///~/Anaconda3/envs/ai/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///~/Anaconda3/envs/ai/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File ~\Anaconda3\envs\ai\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\envs\ai\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'author'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Abubakr\Documents\GitHub\First-Build-Week\data_analyse.ipynb Cell 4' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Abubakr/Documents/GitHub/First-Build-Week/data_analyse.ipynb#ch0000003?line=0'>1</a> def author_best_book(author, df):
#       <a href='vscode-notebook-cell:/c%3A/Users/Abubakr/Documents/GitHub/First-Build-Week/data_analyse.ipynb#ch0000003?line=1'>2</a>     return df[df['author']==author].sort_values('minmax_norm_ratings', ascending=False)['title'].head(1).item(), df[df['author']==author].sort_values('minmax_norm_ratings', ascending=False)['minmax_norm_ratings'].head(1).item()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Abubakr/Documents/GitHub/First-Build-Week/data_analyse.ipynb#ch0000003?line=2'>3</a> ans = author_best_book(author='Harper Lee', df=df)
#       <a href='vscode-notebook-cell:/c%3A/Users/Abubakr/Documents/GitHub/First-Build-Week/data_analyse.ipynb#ch0000003?line=3'>4</a> print("Author's best book is:", ans[0] ,"  The Rating of the book is:", ans[1])
#
# c:\Users\Abubakr\Documents\GitHub\First-Build-Week\data_analyse.ipynb Cell 4' in author_best_book(author, df)
#       <a href='vscode-notebook-cell:/c%3A/Users/Abubakr/Documents/GitHub/First-Build-Week/data_analyse.ipynb#ch0000003?line=0'>1</a> def author_best_book(author, df):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Abubakr/Documents/GitHub/First-Build-Week/data_analyse.ipynb#ch0000003?line=1'>2</a>     return df[df['author']==author].sort_values('minmax_norm_ratings', ascending=False)['title'].head(1).item(), df[df['author']==author].sort_values('minmax_norm_ratings', ascending=False)['minmax_norm_ratings'].head(1).item()
#
# File ~\Anaconda3\envs\ai\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///~/Anaconda3/envs/ai/lib/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///~/Anaconda3/envs/ai/lib/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///~/Anaconda3/envs/ai/lib/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///~/Anaconda3/envs/ai/lib/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///~/Anaconda3/envs/ai/lib/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File ~\Anaconda3\envs\ai\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///~/Anaconda3/envs/ai/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///~/Anaconda3/envs/ai/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
# -> <a href='file:///~/Anaconda3/envs/ai/lib/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>     raise KeyError(key) from err
#    <a href='file:///~/Anaconda3/envs/ai/lib/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a> except TypeError:
#    <a href='file:///~/Anaconda3/envs/ai/lib/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///~/Anaconda3/envs/ai/lib/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///~/Anaconda3/envs/ai/lib/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>     #  the TypeError.
#    <a href='file:///~/Anaconda3/envs/ai/lib/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>     self._check_indexing_error(key)
#
# KeyError: 'author'

# %%
data = df.groupby(['author'])['minmax_norm_ratings'].mean()

# %%
data
# Out:
# author
# A.A. Milne            6.28
# A.S. Byatt            3.67
# Abraham   Verghese    6.05
# Adam Long             7.04
# Adam Silvera          3.96
#                       ...
# Yann Martel           3.90
# Yevgeny Zamyatin      3.85
# Yuval Noah Harari     6.69
# Zora Neale Hurston    4.14
# سید مرتضی مصطفوی      2.80
# Name: minmax_norm_ratings, Length: 589, dtype: float64
